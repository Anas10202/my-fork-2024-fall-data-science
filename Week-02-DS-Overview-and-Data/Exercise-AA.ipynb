# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)
df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.shape
# Out:
# (125, 61)

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.dtypes
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_filtered = df_food.filter(items=['calories_day', 'weight', 'gender'])

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_filtered.isnull().sum()
# Out:
# calories_day    19
# weight           2
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_filtered = df_filtered.dropna()

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
df_filtered['weight'] = pd.to_numeric(df_filtered['weight'], errors='coerce')
df_filtered = df_filtered.dropna(subset=['weight'])

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
df_salary = pd.read_csv('data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv',sep='\t')
df_salary.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# 0                                             55,000
# 1                                             54,600
# 2                                             34,000
# 3                                             62,000
# 4                                             60,000
#
#    How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.  \
# 0                                                0.0
# 1                                             4000.0
# 2                                                NaN
# 3                                             3000.0
# 4                                             7000.0
#
#   Please indicate the currency  \
# 0                          USD
# 1                          GBP
# 2                          USD
# 3                          USD
# 4                          USD
#
#   If "Other," please indicate the currency here:   \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   If your income needs additional context, please provide it here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What country do you work in?  \
# 0                United States
# 1               United Kingdom
# 2                           US
# 3                          USA
# 4                           US
#
#   If you're in the U.S., what state do you work in? What city do you work in?  \
# 0                                     Massachusetts                    Boston
# 1                                               NaN                 Cambridge
# 2                                         Tennessee               Chattanooga
# 3                                         Wisconsin                 Milwaukee
# 4                                    South Carolina                Greenville
#
#   How many years of professional work experience do you have overall?  \
# 0                                          5-7 years
# 1                                       8 - 10 years
# 2                                        2 - 4 years
# 3                                       8 - 10 years
# 4                                       8 - 10 years
#
#   How many years of professional work experience do you have in your field?  \
# 0                                          5-7 years
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
#
#   What is your highest level of education completed? What is your gender?  \
# 0                                    Master's degree                Woman
# 1                                     College degree           Non-binary
# 2                                     College degree                Woman
# 3                                     College degree                Woman
# 4                                     College degree                Woman
#
#   What is your race? (Choose all that apply.)
# 0                                       White
# 1                                       White
# 2                                       White
# 3                                       White
# 4                                       White

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_salary.shape
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  object
#  1   How old are you?                                                                                                                                                                                                                      28062 non-null  object
#  2   What industry do you work in?                                                                                                                                                                                                         27988 non-null  object
#  3   Job title                                                                                                                                                                                                                             28061 non-null  object
#  4   If your job title needs additional context, please clarify here:                                                                                                                                                                      7262 non-null   object
#  5   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  28062 non-null  object
#  6   How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                        20766 non-null  float64
#  7   Please indicate the currency                                                                                                                                                                                                          28062 non-null  object
#  8   If "Other," please indicate the currency here:                                                                                                                                                                                        206 non-null    object
#  9   If your income needs additional context, please provide it here:                                                                                                                                                                      3042 non-null   object
#  10  What country do you work in?                                                                                                                                                                                                          28062 non-null  object
#  11  If you're in the U.S., what state do you work in?                                                                                                                                                                                     23039 non-null  object
#  12  What city do you work in?                                                                                                                                                                                                             27980 non-null  object
#  13  How many years of professional work experience do you have overall?                                                                                                                                                                   28062 non-null  object
#  14  How many years of professional work experience do you have in your field?                                                                                                                                                             28062 non-null  object
#  15  What is your highest level of education completed?                                                                                                                                                                                    27840 non-null  object
#  16  What is your gender?                                                                                                                                                                                                                  27891 non-null  object
#  17  What is your race? (Choose all that apply.)                                                                                                                                                                                           27885 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 3.9+ MB

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.columns = [
    'timestamp',
    'age',
    'industry',
    'title',
    'title_context',
    'salary',
    'additional_compensation',
    'currency',
    'other_currency',
    'salary_context',
    'country',
    'state',
    'city',
    'total_yoe',
    'field_yoe',
    'highest_education_completed',
    'gender',
    'race'
]

df_salary.dtypes
# Out:
# timestamp                       object
# age                             object
# industry                        object
# title                           object
# title_context                   object
# salary                          object
# additional_compensation        float64
# currency                        object
# other_currency                  object
# salary_context                  object
# country                         object
# state                           object
# city                            object
# total_yoe                       object
# field_yoe                       object
# highest_education_completed     object
# gender                          object
# race                            object
# dtype: object

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary['industry'].value_counts()
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
top_5 = df_salary['industry'].value_counts().head(5).index
df_salary_tech=df_salary[df_salary['industry'].isin(top_5)]

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
df_salary_tech.head(20)
# Out:
#              timestamp    age                              industry  \
# 0   4/27/2021 11:02:10  25-34          Education (Higher Education)
# 1   4/27/2021 11:02:22  25-34                     Computing or Tech
# 3   4/27/2021 11:02:41  25-34                            Nonprofits
# 5   4/27/2021 11:02:46  25-34          Education (Higher Education)
# 8   4/27/2021 11:03:01  45-54                     Computing or Tech
# 10  4/27/2021 11:03:03  25-34                            Nonprofits
# 11  4/27/2021 11:03:07  35-44          Education (Higher Education)
# 14  4/27/2021 11:03:11  18-24                           Health care
# 19  4/27/2021 11:03:23  35-44          Education (Higher Education)
# 20  4/27/2021 11:03:24  25-34                           Health care
# 21  4/27/2021 11:03:24  35-44                            Nonprofits
# 22  4/27/2021 11:03:27  35-44                            Nonprofits
# 23  4/27/2021 11:03:29  35-44  Government and Public Administration
# 25  4/27/2021 11:03:34  35-44          Education (Higher Education)
# 26  4/27/2021 11:03:38  25-34                            Nonprofits
# 28  4/27/2021 11:03:41  35-44  Government and Public Administration
# 30  4/27/2021 11:03:44  25-34                            Nonprofits
# 34  4/27/2021 11:03:54  25-34                            Nonprofits
# 35  4/27/2021 11:03:55  35-44          Education (Higher Education)
# 38  4/27/2021 11:03:57  35-44  Government and Public Administration
#
#                                                 title  \
# 0                  Research and Instruction Librarian
# 1            Change & Internal Communications Manager
# 3                                     Program Manager
# 5                      Scholarly Publishing Librarian
# 8                                     Systems Analyst
# 10                                     Office Manager
# 11  Deputy Title IX Coordinator/ Assistant Directo...
# 14                           Patient care coordinator
# 19            Assistant Director of Academic Advising
# 20                            Data Programmer Analyst
# 21            Program Coordinator & Assistant Editor
# 22                                      Event Planner
# 23                                         Researcher
# 25                          Communications Specialist
# 26                                   Program Director
# 28                                          Economist
# 30                   Volunteer and Giving Coordinator
# 34                      Administrative and HR Manager
# 35                                 Senior IRB Analyst
# 38                          Staff Services Manager II
#
#                                         title_context   salary  \
# 0                                                 NaN   55,000
# 1                                                 NaN   54,600
# 3                                                 NaN   62,000
# 5                                                 NaN   62,000
# 8                        Data developer/ETL Developer  112,000
# 10                                                NaN   47,500
# 11                                                NaN   62,000
# 14                                                NaN   32,000
# 19                                                NaN   54,000
# 20                                                NaN   74,000
# 21                                                NaN   50,000
# 22                                                NaN   63,000
# 23                                                NaN   96,000
# 25                                                NaN   60,000
# 26  I manage staff members who each manage 8-15 ot...   62,000
# 28                                                NaN  140,000
# 30                                                NaN   39,000
# 34                                                NaN   50,000
# 35  State university, higher ed research adminstra...   68,000
# 38                      Mid-level manager, team of 13   78,000
#
#     additional_compensation currency other_currency salary_context  \
# 0                       0.0      USD            NaN            NaN
# 1                    4000.0      GBP            NaN            NaN
# 3                    3000.0      USD            NaN            NaN
# 5                       NaN      USD            NaN            NaN
# 8                   10000.0      USD            NaN            NaN
# 10                      0.0      USD            NaN            NaN
# 11                      0.0      USD            NaN            NaN
# 14                      NaN      CAD            NaN            NaN
# 19                      NaN      USD            NaN            NaN
# 20                      0.0      USD            NaN            NaN
# 21                      NaN      USD            NaN            NaN
# 22                      NaN      CAD            NaN            NaN
# 23                   1000.0      USD            NaN            NaN
# 25                      0.0      USD            NaN            NaN
# 26                      NaN      USD            NaN            NaN
# 28                      NaN      USD            NaN            NaN
# 30                      NaN      USD            NaN            NaN
# 34                      NaN      USD            NaN            NaN
# 35                      0.0      USD            NaN            NaN
# 38                      0.0      USD            NaN            NaN
#
#            country                 state               city       total_yoe  \
# 0    United States         Massachusetts             Boston       5-7 years
# 1   United Kingdom                   NaN          Cambridge    8 - 10 years
# 3              USA             Wisconsin          Milwaukee    8 - 10 years
# 5              USA         New Hampshire            Hanover    8 - 10 years
# 8               US              Missouri          St. Louis   21 - 30 years
# 10   United States                   NaN         Boston, MA       5-7 years
# 11             USA          Pennsylvania           Scranton   11 - 20 years
# 14          Canada                   NaN             Remote  1 year or less
# 19   United States               Florida         Boca Raton   11 - 20 years
# 20             USA          Pennsylvania       Philadelphia       5-7 years
# 21   United States                   NaN            Atlanta       5-7 years
# 22          Canada                   NaN            Toronto   11 - 20 years
# 23   United States                  Ohio             Dayton    8 - 10 years
# 25             USA              Michigan          Ann Arbor   11 - 20 years
# 26              US  District of Columbia      Washington DC       5-7 years
# 28             USA  District of Columbia         Washington   11 - 20 years
# 30   United States             Minnesota        Minneapolis     2 - 4 years
# 34   United States  District of Columbia         Washington       5-7 years
# 35             USA        North Carolina  Research Triangle       5-7 years
# 38             USA            California         Sacramento    8 - 10 years
#
#          field_yoe highest_education_completed      gender  \
# 0        5-7 years             Master's degree       Woman
# 1        5-7 years              College degree  Non-binary
# 3        5-7 years              College degree       Woman
# 5      2 - 4 years             Master's degree         Man
# 8    21 - 30 years              College degree       Woman
# 10       5-7 years              College degree       Woman
# 11       5-7 years                         PhD       Woman
# 14  1 year or less              College degree       Woman
# 19   11 - 20 years             Master's degree       Woman
# 20       5-7 years             Master's degree       Woman
# 21     2 - 4 years                         PhD       Woman
# 22    8 - 10 years             Master's degree       Woman
# 23     2 - 4 years                         PhD       Woman
# 25  1 year or less             Master's degree       Woman
# 26     2 - 4 years              College degree         Man
# 28   11 - 20 years             Master's degree       Woman
# 30     2 - 4 years              College degree       Woman
# 34     2 - 4 years              College degree       Woman
# 35     2 - 4 years             Master's degree       Woman
# 38       5-7 years             Master's degree       Woman
#
#                                           race
# 0                                        White
# 1                                        White
# 3                                        White
# 5                                        White
# 8                                        White
# 10                                       White
# 11  Hispanic, Latino, or Spanish origin, White
# 14                                       White
# 19                                       White
# 20                                       White
# 21                                       White
# 22                                       White
# 23                     Asian or Asian American
# 25                                       White
# 26                                       White
# 28                                       White
# 30                                       White
# 34                                       White
# 35                                       White
# 38                                       White

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
df_usd=df_salary_tech[df_salary_tech['currency']=='USD']

df_usd.head()
# Out:
#              timestamp    age                      industry  \
# 0   4/27/2021 11:02:10  25-34  Education (Higher Education)
# 3   4/27/2021 11:02:41  25-34                    Nonprofits
# 5   4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8   4/27/2021 11:03:01  45-54             Computing or Tech
# 10  4/27/2021 11:03:03  25-34                    Nonprofits
#
#                                  title                 title_context   salary  \
# 0   Research and Instruction Librarian                           NaN   55,000
# 3                      Program Manager                           NaN   62,000
# 5       Scholarly Publishing Librarian                           NaN   62,000
# 8                      Systems Analyst  Data developer/ETL Developer  112,000
# 10                      Office Manager                           NaN   47,500
#
#     additional_compensation currency other_currency salary_context  \
# 0                       0.0      USD            NaN            NaN
# 3                    3000.0      USD            NaN            NaN
# 5                       NaN      USD            NaN            NaN
# 8                   10000.0      USD            NaN            NaN
# 10                      0.0      USD            NaN            NaN
#
#           country          state        city      total_yoe      field_yoe  \
# 0   United States  Massachusetts      Boston      5-7 years      5-7 years
# 3             USA      Wisconsin   Milwaukee   8 - 10 years      5-7 years
# 5             USA  New Hampshire     Hanover   8 - 10 years    2 - 4 years
# 8              US       Missouri   St. Louis  21 - 30 years  21 - 30 years
# 10  United States            NaN  Boston, MA      5-7 years      5-7 years
#
#    highest_education_completed gender   race
# 0              Master's degree  Woman  White
# 3               College degree  Woman  White
# 5              Master's degree    Man  White
# 8               College degree  Woman  White
# 10              College degree  Woman  White

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_usd['country'].value_counts()
# Out:
# country
# United States     4318
# USA               3813
# US                1252
# U.S.               292
# United States      255
#                   ...
# Sri lanka            1
# Bangladesh           1
# United Statea        1
# Contracts            1
# Burma                1
# Name: count, Length: 139, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
top_5_country=df_usd['country'].value_counts().head(5).index
df_usd.loc[df_usd['country'].isin(top_5_country), 'country'] = 'US'

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_usd['country'].value_counts()
# Out:
# country
# US                           10789
# U.S.A.                          19
# United States of America        19
# U.S                             14
# US                              12
#                              ...
#  US                              1
# Hartford                         1
# USS                              1
# Puerto Rico                      1
# Burma                            1
# Name: count, Length: 127, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
